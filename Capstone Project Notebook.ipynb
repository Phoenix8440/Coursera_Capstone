# %% [markdown]
# # Battle of the Neighborhoods in Tokyo Capstone

# %% [markdown]
# ## Created by Jason Robson

# %% [markdown]
# <br />
#
# ## Table of Contents

# %% [markdown]
# ### 1. Retrieve database and clean data. Determine Latitude and Longitude.
# <br />
#
# ### 2. Log into FourSquare
# <br />
#
# ### 3. Collect data on coffee shops and restaurants
# <br />
#
# ### 4. Cluster data
# <br />
#
# ### 5. Create map

# %% [markdown]
# <br />

# %% [markdown]
# ### 1. Retrieve database and clean data.

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import os
from sklearn.cluster import KMeans
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
# !conda install -c conda-forge lxml --yes

# %% [markdown]
# ### Pandas is used to transform the data into a dataframe. Data is taken from Wikipedia.

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/Special_wards_of_Tokyo#List_of_special_wards') [3]
df

# %% [markdown]
# ### Data is cleaned

# %%
df.drop("Flag", axis=1, inplace=True)
df.drop("Kanji", axis=1, inplace=True)
df.rename(columns={df.columns[2]:"Population"}, inplace=True)
df = df.rename(columns={"Density(/km2)": "Density"})
df = df.rename(columns={"Area(km2)": "Area"})
df.drop([23], inplace=True)
df

# %% [markdown]
# ### Coordinates are determined and new table is pictured

# %%
geolocator = Nominatim(user_agent="Tokyo_explorer")

df['Major_Districts']= df['Name'].apply(geolocator.geocode).apply(lambda x: (x.latitude, x.longitude))
df[['Latitude', 'Longitude']] = df['Major_Districts'].apply(pd.Series)

df.drop(['Major_Districts'], axis=1, inplace=True)
df
# Out:
#    No.        Name  Population  Density   Area  \
# 0   01     Chiyoda       59441     5100  11.66
# 1   02        Chūō      147620    14460  10.21
# 2   03      Minato      248071    12180  20.37
# 3   04    Shinjuku      339211    18620  18.22
# 4   05      Bunkyō      223389    19790  11.29
# 5   06       Taitō      200486    19830  10.11
# 6   07      Sumida      260358    18910  13.77
# 7   08        Kōtō      502579    12510  40.16
# 8   09   Shinagawa      392492    17180  22.84
# 9   10      Meguro      280283    19110  14.67
# 10  11         Ōta      722608    11910  60.66
# 11  12    Setagaya      910868    15690  58.05
# 12  13     Shibuya      227850    15080  15.11
# 13  14      Nakano      332902    21350  15.59
# 14  15    Suginami      570483    16750  34.06
# 15  16     Toshima      294673    22650  13.01
# 16  17        Kita      345063    16740  20.61
# 17  18     Arakawa      213648    21030  10.16
# 18  19    Itabashi      569225    17670  32.22
# 19  20      Nerima      726748    15120  48.08
# 20  21      Adachi      674067    12660  53.25
# 21  22  Katsushika      447140    12850  34.80
# 22  23     Edogawa      685899    13750  49.90
#
#                                       Major districts   Latitude   Longitude
# 0   Nagatachō, Kasumigaseki, Ōtemachi, Marunouchi,...  35.693810  139.753216
# 1   Nihonbashi, Kayabachō, Ginza, Tsukiji, Hatchōb...  35.666255  139.775565
# 2   Odaiba, Shinbashi, Hamamatsuchō, Mita, Roppong...  35.643227  139.740055
# 3   Shinjuku, Takadanobaba, Ōkubo, Kagurazaka, Ich...  35.693763  139.703632
# 4                               Hongō, Yayoi, Hakusan  35.718810  139.744732
# 5                                       Ueno, Asakusa  35.717450  139.790859
# 6                       Kinshichō, Morishita, Ryōgoku  35.700429  139.805017
# 7   Kiba, Ariake, Kameido, Tōyōchō, Monzennakachō,...  35.649154  139.812790
# 8   Shinagawa, Gotanda, Ōsaki, Hatanodai, Ōimachi,...  35.599252  139.738910
# 9      Meguro, Nakameguro, Jiyugaoka, Komaba, Aobadai  35.621250  139.688014
# 10                Ōmori, Kamata, Haneda, Den-en-chōfu  35.561206  139.715843
# 11  Setagaya, Shimokitazawa, Kinuta, Karasuyama, T...  35.646096  139.656270
# 12  Shibuya, Ebisu, Harajuku, Daikanyama, Hiroo, S...  35.664596  139.698711
# 13                                             Nakano  35.718123  139.664468
# 14                           Kōenji, Asagaya, Ogikubo  35.699493  139.636288
# 15               Ikebukuro, Komagome, Senkawa, Sugamo  35.736156  139.714222
# 16                               Akabane, Ōji, Tabata  -0.220164  -78.512327
# 17             Arakawa, Machiya, Nippori, Minamisenju  35.737529  139.781310
# 18                           Itabashi, Takashimadaira  35.774143  139.681209
# 19                        Nerima, Ōizumi, Hikarigaoka  35.748360  139.638735
# 20                      Ayase, Kitasenju, Takenotsuka  35.783703  139.795319
# 21                 Tateishi, Aoto, Kameari, Shibamata  35.751733  139.863816
# 22                                       Kasai, Koiwa  35.678278  139.871091

# %% [markdown]
# ### 2. Foursquare Login

# %% [markdown]
# ### Venues near Tokyo special wards are retrieved.

# %%
CLIENT_ID = 'WL5230EQST0RNTHM4RACIFYTZXHGFUIMNRYICERYSR1UZ3QE'
CLIENT_SECRET = 'RODQMYVAL5ZGX1EFOTWJPUV40XHDV42DADTVBEKSCLLHCN3N'
VERSION = '20200601'

# %%
def getNearbyVenues(names, latitudes, longitudes):
    radius=500
    LIMIT=100
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Ward', 
                  'Ward Latitude', 
                  'Ward Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
Tokyo_venues = getNearbyVenues(names=df['Name'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Chiyoda
# Chūō
# Minato
# Shinjuku
# Bunkyō
# Taitō
# Sumida
# Kōtō
# Shinagawa
# Meguro
# Ōta
# Setagaya
# Shibuya
# Nakano
# Suginami
# Toshima
# Kita
# Arakawa
# Itabashi
# Nerima
# Adachi
# Katsushika
# Edogawa

# %% [markdown]
# ### 3. Collect data on coffee shops and restaurants.

# %% [markdown]
# ### Determine unique categories and count

# %%
Tokyo_venues_coffee = Tokyo_venues[Tokyo_venues['Venue Category'].str.contains('Coffee')].reset_index(drop=True)
Tokyo_venues_coffee.index = np.arange(1, len(Tokyo_venues_coffee )+1)

print (Tokyo_venues_coffee['Venue Category'].value_counts())
# Out:
# Coffee Shop    31
# Name: Venue Category, dtype: int64

# %%
print('There are {} unique categories.'.format(len(Tokyo_venues_coffee['Venue Category'].unique())))
# Out:
# There are 1 unique categories.

# %%
Tokyo_venues_restaurants = Tokyo_venues[Tokyo_venues['Venue Category'].str.contains('Restaurant')].reset_index(drop=True)
Tokyo_venues_restaurants.index = np.arange(1, len(Tokyo_venues_restaurants )+1)

print (Tokyo_venues_restaurants['Venue Category'].value_counts())
# Out:
# Ramen Restaurant                 52
# Japanese Restaurant              45
# Chinese Restaurant               34
# Sushi Restaurant                 28
# Italian Restaurant               22
# Soba Restaurant                  20
# Restaurant                       18
# Donburi Restaurant               10
# Tonkatsu Restaurant               9
# Indian Restaurant                 8
# French Restaurant                 7
# Unagi Restaurant                  6
# Yoshoku Restaurant                5
# Dumpling Restaurant               5
# Japanese Curry Restaurant         5
# Korean Restaurant                 4
# Yakitori Restaurant               4
# Seafood Restaurant                4
# Thai Restaurant                   3
# Tempura Restaurant                2
# South American Restaurant         2
# Szechuan Restaurant               2
# Brazilian Restaurant              2
# Sukiyaki Restaurant               2
# Hotpot Restaurant                 1
# Kaiseki Restaurant                1
# Spanish Restaurant                1
# Dongbei Restaurant                1
# South Indian Restaurant           1
# German Restaurant                 1
# Shabu-Shabu Restaurant            1
# Mongolian Restaurant              1
# Kushikatsu Restaurant             1
# Kosher Restaurant                 1
# Kebab Restaurant                  1
# Taiwanese Restaurant              1
# Udon Restaurant                   1
# Nabe Restaurant                   1
# Fast Food Restaurant              1
# Asian Restaurant                  1
# Vegetarian / Vegan Restaurant     1
# Vietnamese Restaurant             1
# Monjayaki Restaurant              1
# Middle Eastern Restaurant         1
# Cajun / Creole Restaurant         1
# Name: Venue Category, dtype: int64

# %%
print('There are {} unique categories.'.format(len(Tokyo_venues_restaurants['Venue Category'].unique())))
# Out:
# There are 45 unique categories.

# %% [markdown]
# ### Determine frequencies of coffee shops and restaurants.

# %%
Tokyo_Dist_venues_Top5 = Tokyo_venues_coffee['Venue Category'].value_counts()[0:5].to_frame(name='frequency')
Tokyo_Dist_venues_Top5=Tokyo_Dist_venues_Top5.reset_index()


Tokyo_Dist_venues_Top5.rename(index=str, columns={"index": "Venue Category", "frequency": "Frequency"}, inplace=True)
Tokyo_Dist_venues_Top5
# Out:
#   Venue Category  Frequency
# 0    Coffee Shop         31

# %%
Tokyo_Dist_venues_Top15 = Tokyo_venues_restaurants['Venue Category'].value_counts()[0:15].to_frame(name='frequency')
Tokyo_Dist_venues_Top15=Tokyo_Dist_venues_Top15.reset_index()


Tokyo_Dist_venues_Top15.rename(index=str, columns={"index": "Venue Category", "frequency": "Frequency"}, inplace=True)
Tokyo_Dist_venues_Top15
# Out:
#                Venue Category  Frequency
# 0            Ramen Restaurant         52
# 1         Japanese Restaurant         45
# 2          Chinese Restaurant         34
# 3            Sushi Restaurant         28
# 4          Italian Restaurant         22
# 5             Soba Restaurant         20
# 6                  Restaurant         18
# 7          Donburi Restaurant         10
# 8         Tonkatsu Restaurant          9
# 9           Indian Restaurant          8
# 10          French Restaurant          7
# 11           Unagi Restaurant          6
# 12         Yoshoku Restaurant          5
# 13        Dumpling Restaurant          5
# 14  Japanese Curry Restaurant          5

# %% [markdown]
# ### Tokyo coffee shops by Ward

# %%
Tokyo_venues_coffee.head(15)
# Out:
#         Ward  Ward Latitude  Ward Longitude                         Venue  \
# 1    Chiyoda      35.693810      139.753216    Mi Cafeto Café & Brasserie
# 2    Chiyoda      35.693810      139.753216                     Starbucks
# 3    Chiyoda      35.693810      139.753216                     Starbucks
# 4    Chiyoda      35.693810      139.753216               EXCELSIOR CAFFÉ
# 5    Chiyoda      35.693810      139.753216      St. Marc Café (サンマルクカフェ)
# 6    Chiyoda      35.693810      139.753216                     Starbucks
# 7    Chiyoda      35.693810      139.753216  Ueshima Coffee House (上島珈琲店)
# 8       Chūō      35.666255      139.775565                 Turret COFFEE
# 9       Chūō      35.666255      139.775565         Live Coffee (ライブコーヒー)
# 10      Chūō      35.666255      139.775565                Tully's Coffee
# 11      Chūō      35.666255      139.775565      Caffè Veloce (カフェ・ベローチェ)
# 12    Minato      35.643227      139.740055    Segafredo Zanetti Espresso
# 13  Shinjuku      35.693763      139.703632      Tajimaya Coffee (但馬屋珈琲店)
# 14     Taitō      35.717450      139.790859       Kappabashi Coffee & Bar
# 15     Taitō      35.717450      139.790859            DAVIDE COFFEE STOP
#
#     Venue Latitude  Venue Longitude Venue Category
# 1        35.694187       139.758268    Coffee Shop
# 2        35.690846       139.757197    Coffee Shop
# 3        35.695789       139.752266    Coffee Shop
# 4        35.696766       139.751164    Coffee Shop
# 5        35.690660       139.756979    Coffee Shop
# 6        35.695611       139.750705    Coffee Shop
# 7        35.690824       139.757217    Coffee Shop
# 8        35.668105       139.771903    Coffee Shop
# 9        35.668185       139.773762    Coffee Shop
# 10       35.667762       139.774028    Coffee Shop
# 11       35.668101       139.772963    Coffee Shop
# 12       35.644788       139.745053    Coffee Shop
# 13       35.692682       139.699701    Coffee Shop
# 14       35.716770       139.789352    Coffee Shop
# 15       35.718417       139.788486    Coffee Shop

# %% [markdown]
# ### Tokyo restaurants by Ward

# %%
Tokyo_venues_restaurants.head(15)
# Out:
#        Ward  Ward Latitude  Ward Longitude                       Venue  \
# 1   Chiyoda       35.69381      139.753216    Jimbocho Kurosu (神保町 黒須)
# 2   Chiyoda       35.69381      139.753216          Bondy (欧風カレー ボンディ)
# 3   Chiyoda       35.69381      139.753216        Sushi Masa (九段下 寿司政)
# 4   Chiyoda       35.69381      139.753216                       たいよう軒
# 5   Chiyoda       35.69381      139.753216         Fukumen Tomo (覆麺 智)
# 6   Chiyoda       35.69381      139.753216                        咸亨酒店
# 7   Chiyoda       35.69381      139.753216               Yojinbo (用心棒)
# 8   Chiyoda       35.69381      139.753216                         三希房
# 9   Chiyoda       35.69381      139.753216                        ぴえもん
# 10  Chiyoda       35.69381      139.753216              Mandala (マンダラ)
# 11  Chiyoda       35.69381      139.753216      Kitchen Jiro (キッチンジロー)
# 12  Chiyoda       35.69381      139.753216  Ramen Jiro (ラーメン二郎 神田神保町店)
# 13  Chiyoda       35.69381      139.753216              Sankouen (三幸園)
# 14  Chiyoda       35.69381      139.753216      Tanaka Sobaten (田中そば店)
# 15  Chiyoda       35.69381      139.753216                  カレーの店 タカサゴ
#
#     Venue Latitude  Venue Longitude             Venue Category
# 1        35.695539       139.754851           Ramen Restaurant
# 2        35.695544       139.757356  Japanese Curry Restaurant
# 3        35.695234       139.752227           Sushi Restaurant
# 4        35.696454       139.754809         Chinese Restaurant
# 5        35.696403       139.757070           Ramen Restaurant
# 6        35.696010       139.756730         Chinese Restaurant
# 7        35.696409       139.756696           Ramen Restaurant
# 8        35.697159       139.750652         Chinese Restaurant
# 9        35.696472       139.751240         Italian Restaurant
# 10       35.695413       139.757691          Indian Restaurant
# 11       35.696817       139.751889         Yoshoku Restaurant
# 12       35.696390       139.756477           Ramen Restaurant
# 13       35.695086       139.758478         Chinese Restaurant
# 14       35.696468       139.751222           Ramen Restaurant
# 15       35.690834       139.756924  Japanese Curry Restaurant

# %% [markdown]
# ### Coffee shop count by Ward

# %%
Tokyo_venues_coffee_ncount = Tokyo_venues_coffee.groupby(['Ward'])['Venue Category'].apply(lambda x: x[x.str.contains('Coffee Shop')].count())
Tokyo_venues_coffee_ncount
# Out:
# Ward
# Chiyoda       7
# Chūō          4
# Katsushika    2
# Kita          3
# Meguro        1
# Minato        1
# Nakano        1
# Shibuya       3
# Shinjuku      1
# Suginami      1
# Sumida        1
# Taitō         6
# Name: Venue Category, dtype: int64

# %% [markdown]
# ### Restaurant count by Ward

# %%
Tokyo_venues_restaurants_ncount = Tokyo_venues_restaurants.groupby(['Ward'])['Venue Category'].apply(lambda x: x[x.str.contains('Restaurant')].count())
Tokyo_venues_restaurants_ncount
# Out:
# Ward
# Adachi         3
# Arakawa        9
# Bunkyō         4
# Chiyoda       31
# Chūō          57
# Edogawa        2
# Itabashi       3
# Katsushika     7
# Kita          16
# Kōtō           2
# Meguro         6
# Minato        11
# Nakano         9
# Nerima         1
# Setagaya       8
# Shibuya       20
# Shinagawa      6
# Shinjuku      26
# Suginami      10
# Sumida         6
# Taitō         24
# Toshima       18
# Ōta           41
# Name: Venue Category, dtype: int64

# %% [markdown]
# ### Coffee shop array

# %%
Tokyo_venues_coffee_df  = Tokyo_venues_coffee_ncount.to_frame().reset_index()
Tokyo_venues_coffee_df.columns = ['Ward', 'Number of Coffee Shops']
Tokyo_venues_coffee_df.index = np.arange(1, len(Tokyo_venues_coffee_df)+1)
list_rest_no =Tokyo_venues_coffee_df['Number of Coffee Shops'].to_list()
list_dist =Tokyo_venues_coffee_df['Ward'].to_list()
print(list_rest_no)
print(list_dist)
# Out:
# [7, 4, 2, 3, 1, 1, 1, 3, 1, 1, 1, 6]
# ['Chiyoda', 'Chūō', 'Katsushika', 'Kita', 'Meguro', 'Minato', 'Nakano', 'Shibuya', 'Shinjuku', 'Suginami', 'Sumida', 'Taitō']

# %% [markdown]
# ### Restaurant array

# %%
Tokyo_venues_restaurants_df  = Tokyo_venues_restaurants_ncount.to_frame().reset_index()
Tokyo_venues_restaurants_df.columns = ['Ward', 'Number of Restaurants']
Tokyo_venues_restaurants_df.index = np.arange(1, len(Tokyo_venues_restaurants_df)+1)
list_rest_no =Tokyo_venues_restaurants_df['Number of Restaurants'].to_list()
list_dist =Tokyo_venues_restaurants_df['Ward'].to_list()
print(list_rest_no)
print(list_dist)
# Out:
# [3, 9, 4, 31, 57, 2, 3, 7, 16, 2, 6, 11, 9, 1, 8, 20, 6, 26, 10, 6, 24, 18, 41]
# ['Adachi', 'Arakawa', 'Bunkyō', 'Chiyoda', 'Chūō', 'Edogawa', 'Itabashi', 'Katsushika', 'Kita', 'Kōtō', 'Meguro', 'Minato', 'Nakano', 'Nerima', 'Setagaya', 'Shibuya', 'Shinagawa', 'Shinjuku', 'Suginami', 'Sumida', 'Taitō', 'Toshima', 'Ōta']

# %% [markdown]
# ### Tokyo coffee mean and frequency by Ward

# %%
Tokyo_onehot_c = pd.get_dummies(Tokyo_venues_coffee[['Venue Category']], prefix="", prefix_sep="")

Tokyo_onehot_c.insert(loc=0, column='Ward', value=Tokyo_venues_coffee["Ward"] )
Tokyo_grouped_c = Tokyo_onehot_c.groupby('Ward').mean().reset_index()
Tokyo_grouped_c.head()
# Out:
#          Ward  Coffee Shop
# 0     Chiyoda            1
# 1        Chūō            1
# 2  Katsushika            1
# 3        Kita            1
# 4      Meguro            1

# %%
num_top_venues_c = 5

for hood in Tokyo_grouped_c['Ward']:
    print("----"+hood+"----")
    temp = Tokyo_grouped_c[Tokyo_grouped_c['Ward'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues_c))
    print('\n')
# Out:
# ----Chiyoda----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Chūō----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Katsushika----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Kita----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Meguro----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Minato----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Nakano----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Shibuya----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Shinjuku----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Suginami----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Sumida----
#          venue  freq
# 0  Coffee Shop   1.0
#
#
# ----Taitō----
#          venue  freq
# 0  Coffee Shop   1.0

# %% [markdown]
# ### Tokyo restaurant mean and frequency by Ward

# %%
Tokyo_onehot_r = pd.get_dummies(Tokyo_venues_restaurants[['Venue Category']], prefix="", prefix_sep="")

Tokyo_onehot_r.insert(loc=0, column='Ward', value=Tokyo_venues_restaurants["Ward"] )
Tokyo_grouped_r = Tokyo_onehot_r.groupby('Ward').mean().reset_index()
Tokyo_grouped_r.head()
# Out:
#       Ward  Asian Restaurant  Brazilian Restaurant  Cajun / Creole Restaurant  \
# 0   Adachi               0.0                   0.0                        0.0
# 1  Arakawa               0.0                   0.0                        0.0
# 2   Bunkyō               0.0                   0.0                        0.0
# 3  Chiyoda               0.0                   0.0                        0.0
# 4     Chūō               0.0                   0.0                        0.0
#
#    Chinese Restaurant  Donburi Restaurant  Dongbei Restaurant  \
# 0            0.000000            0.000000                 0.0
# 1            0.222222            0.111111                 0.0
# 2            0.250000            0.000000                 0.0
# 3            0.161290            0.000000                 0.0
# 4            0.000000            0.035088                 0.0
#
#    Dumpling Restaurant  Fast Food Restaurant  French Restaurant  ...  \
# 0                  0.0                   0.0           0.000000  ...
# 1                  0.0                   0.0           0.000000  ...
# 2                  0.0                   0.0           0.000000  ...
# 3                  0.0                   0.0           0.064516  ...
# 4                  0.0                   0.0           0.017544  ...
#
#    Taiwanese Restaurant  Tempura Restaurant  Thai Restaurant  \
# 0                   0.0            0.000000         0.000000
# 1                   0.0            0.000000         0.000000
# 2                   0.0            0.000000         0.000000
# 3                   0.0            0.000000         0.032258
# 4                   0.0            0.035088         0.000000
#
#    Tonkatsu Restaurant  Udon Restaurant  Unagi Restaurant  \
# 0             0.000000              0.0          0.000000
# 1             0.000000              0.0          0.000000
# 2             0.000000              0.0          0.000000
# 3             0.032258              0.0          0.000000
# 4             0.017544              0.0          0.035088
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant  Yakitori Restaurant  \
# 0                            0.0                    0.0             0.000000
# 1                            0.0                    0.0             0.000000
# 2                            0.0                    0.0             0.000000
# 3                            0.0                    0.0             0.000000
# 4                            0.0                    0.0             0.017544
#
#    Yoshoku Restaurant
# 0            0.000000
# 1            0.000000
# 2            0.000000
# 3            0.032258
# 4            0.017544
#
# [5 rows x 46 columns]

# %%
num_top_venues_r = 8

for hood in Tokyo_grouped_r['Ward']:
    print("----"+hood+"----")
    temp = Tokyo_grouped_r[Tokyo_grouped_r['Ward'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues_r))
    print('\n')
# Out:
# ----Adachi----
#                        venue  freq
# 0                 Restaurant  0.33
# 1         Italian Restaurant  0.33
# 2        Japanese Restaurant  0.33
# 3         Seafood Restaurant  0.00
# 4     Shabu-Shabu Restaurant  0.00
# 5            Soba Restaurant  0.00
# 6  South American Restaurant  0.00
# 7    South Indian Restaurant  0.00
#
#
# ----Arakawa----
#                  venue  freq
# 0     Ramen Restaurant  0.22
# 1   Chinese Restaurant  0.22
# 2   Donburi Restaurant  0.11
# 3    Indian Restaurant  0.11
# 4   Italian Restaurant  0.11
# 5    Korean Restaurant  0.11
# 6  Japanese Restaurant  0.11
# 7     Asian Restaurant  0.00
#
#
# ----Bunkyō----
#                     venue  freq
# 0     Szechuan Restaurant  0.25
# 1      Chinese Restaurant  0.25
# 2       Indian Restaurant  0.25
# 3     Japanese Restaurant  0.25
# 4        Asian Restaurant  0.00
# 5      Seafood Restaurant  0.00
# 6  Shabu-Shabu Restaurant  0.00
# 7         Soba Restaurant  0.00
#
#
# ----Chiyoda----
#                        venue  freq
# 0           Ramen Restaurant  0.23
# 1         Chinese Restaurant  0.16
# 2  Japanese Curry Restaurant  0.10
# 3          Indian Restaurant  0.10
# 4          French Restaurant  0.06
# 5        Japanese Restaurant  0.06
# 6         Italian Restaurant  0.06
# 7                 Restaurant  0.06
#
#
# ----Chūō----
#                  venue  freq
# 0     Sushi Restaurant  0.32
# 1  Japanese Restaurant  0.23
# 2      Soba Restaurant  0.07
# 3   Seafood Restaurant  0.05
# 4   Italian Restaurant  0.05
# 5     Ramen Restaurant  0.04
# 6   Donburi Restaurant  0.04
# 7     Unagi Restaurant  0.04
#
#
# ----Edogawa----
#                        venue  freq
# 0           Ramen Restaurant   0.5
# 1         Italian Restaurant   0.5
# 2                 Restaurant   0.0
# 3         Seafood Restaurant   0.0
# 4     Shabu-Shabu Restaurant   0.0
# 5            Soba Restaurant   0.0
# 6  South American Restaurant   0.0
# 7    South Indian Restaurant   0.0
#
#
# ----Itabashi----
#                        venue  freq
# 0         Chinese Restaurant  0.67
# 1         Italian Restaurant  0.33
# 2           Asian Restaurant  0.00
# 3         Seafood Restaurant  0.00
# 4     Shabu-Shabu Restaurant  0.00
# 5            Soba Restaurant  0.00
# 6  South American Restaurant  0.00
# 7    South Indian Restaurant  0.00
#
#
# ----Katsushika----
#                     venue  freq
# 0      Donburi Restaurant  0.29
# 1        Ramen Restaurant  0.14
# 2     Japanese Restaurant  0.14
# 3     Dumpling Restaurant  0.14
# 4       Korean Restaurant  0.14
# 5       Indian Restaurant  0.14
# 6  Shabu-Shabu Restaurant  0.00
# 7         Soba Restaurant  0.00
#
#
# ----Kita----
#                            venue  freq
# 0                     Restaurant  0.62
# 1      South American Restaurant  0.12
# 2      Cajun / Creole Restaurant  0.06
# 3             Seafood Restaurant  0.06
# 4  Vegetarian / Vegan Restaurant  0.06
# 5              French Restaurant  0.06
# 6            Szechuan Restaurant  0.00
# 7         Shabu-Shabu Restaurant  0.00
#
#
# ----Kōtō----
#                        venue  freq
# 0                 Restaurant   0.5
# 1         Chinese Restaurant   0.5
# 2           Asian Restaurant   0.0
# 3        Szechuan Restaurant   0.0
# 4         Seafood Restaurant   0.0
# 5     Shabu-Shabu Restaurant   0.0
# 6            Soba Restaurant   0.0
# 7  South American Restaurant   0.0
#
#
# ----Meguro----
#                     venue  freq
# 0      Chinese Restaurant  0.33
# 1     Japanese Restaurant  0.33
# 2      Italian Restaurant  0.17
# 3        Sushi Restaurant  0.17
# 4     Szechuan Restaurant  0.00
# 5      Seafood Restaurant  0.00
# 6  Shabu-Shabu Restaurant  0.00
# 7         Soba Restaurant  0.00
#
#
# ----Minato----
#                  venue  freq
# 0      Soba Restaurant  0.27
# 1     Kebab Restaurant  0.09
# 2  Yakitori Restaurant  0.09
# 3   Chinese Restaurant  0.09
# 4    French Restaurant  0.09
# 5    Indian Restaurant  0.09
# 6    Kosher Restaurant  0.09
# 7  Japanese Restaurant  0.09
#
#
# ----Nakano----
#                  venue  freq
# 0     Ramen Restaurant  0.33
# 1   Italian Restaurant  0.22
# 2   Donburi Restaurant  0.11
# 3    Korean Restaurant  0.11
# 4   Chinese Restaurant  0.11
# 5  Japanese Restaurant  0.11
# 6  Yakitori Restaurant  0.00
# 7  Szechuan Restaurant  0.00
#
#
# ----Nerima----
#                        venue  freq
# 0         Chinese Restaurant   1.0
# 1           Asian Restaurant   0.0
# 2        Szechuan Restaurant   0.0
# 3                 Restaurant   0.0
# 4         Seafood Restaurant   0.0
# 5     Shabu-Shabu Restaurant   0.0
# 6            Soba Restaurant   0.0
# 7  South American Restaurant   0.0
#
#
# ----Setagaya----
#                     venue  freq
# 0              Restaurant  0.25
# 1        Ramen Restaurant  0.25
# 2     Japanese Restaurant  0.12
# 3        Unagi Restaurant  0.12
# 4    Fast Food Restaurant  0.12
# 5     Szechuan Restaurant  0.12
# 6      Seafood Restaurant  0.00
# 7  Shabu-Shabu Restaurant  0.00
#
#
# ----Shibuya----
#                   venue  freq
# 0      Ramen Restaurant  0.20
# 1    Chinese Restaurant  0.20
# 2     French Restaurant  0.10
# 3   Japanese Restaurant  0.10
# 4      Sushi Restaurant  0.10
# 5    Donburi Restaurant  0.05
# 6  Brazilian Restaurant  0.05
# 7  Mongolian Restaurant  0.05
#
#
# ----Shinagawa----
#                     venue  freq
# 0      Donburi Restaurant  0.33
# 1              Restaurant  0.17
# 2         Soba Restaurant  0.17
# 3     Japanese Restaurant  0.17
# 4        Sushi Restaurant  0.17
# 5     Szechuan Restaurant  0.00
# 6      Seafood Restaurant  0.00
# 7  Shabu-Shabu Restaurant  0.00
#
#
# ----Shinjuku----
#                  venue  freq
# 0     Ramen Restaurant  0.27
# 1   Chinese Restaurant  0.12
# 2   Italian Restaurant  0.12
# 3  Japanese Restaurant  0.12
# 4      Soba Restaurant  0.08
# 5  Tonkatsu Restaurant  0.08
# 6   Yoshoku Restaurant  0.04
# 7  Yakitori Restaurant  0.04
#
#
# ----Suginami----
#                  venue  freq
# 0     Ramen Restaurant   0.3
# 1   Italian Restaurant   0.2
# 2     Asian Restaurant   0.1
# 3  Dumpling Restaurant   0.1
# 4      Soba Restaurant   0.1
# 5   Chinese Restaurant   0.1
# 6  Japanese Restaurant   0.1
# 7  Szechuan Restaurant   0.0
#
#
# ----Sumida----
#                     venue  freq
# 0     Japanese Restaurant  0.33
# 1      Chinese Restaurant  0.17
# 2        Unagi Restaurant  0.17
# 3     Tonkatsu Restaurant  0.17
# 4        Ramen Restaurant  0.17
# 5        Asian Restaurant  0.00
# 6      Seafood Restaurant  0.00
# 7  Shabu-Shabu Restaurant  0.00
#
#
# ----Taitō----
#                  venue  freq
# 0      Soba Restaurant  0.21
# 1     Ramen Restaurant  0.17
# 2  Japanese Restaurant  0.12
# 3     Sushi Restaurant  0.12
# 4  Sukiyaki Restaurant  0.08
# 5   Italian Restaurant  0.08
# 6     Unagi Restaurant  0.04
# 7           Restaurant  0.04
#
#
# ----Toshima----
#                        venue  freq
# 0           Ramen Restaurant  0.28
# 1            Soba Restaurant  0.11
# 2         Chinese Restaurant  0.11
# 3        Japanese Restaurant  0.11
# 4            Udon Restaurant  0.06
# 5  Middle Eastern Restaurant  0.06
# 6            Thai Restaurant  0.06
# 7        Tonkatsu Restaurant  0.06
#
#
# ----Ōta----
#                  venue  freq
# 0     Ramen Restaurant  0.24
# 1  Japanese Restaurant  0.17
# 2   Chinese Restaurant  0.15
# 3  Dumpling Restaurant  0.07
# 4  Tonkatsu Restaurant  0.07
# 5   Italian Restaurant  0.05
# 6     Sushi Restaurant  0.05
# 7   Yoshoku Restaurant  0.02

# %% [markdown]
# ### Tokyo top ten venues (restaurant) by Ward

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']


columns = ['Ward']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))


neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Ward'] = Tokyo_grouped['Ward']

for ind in np.arange(Tokyo_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Tokyo_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head(23)
# Out:
#           Ward 1st Most Common Venue      2nd Most Common Venue  \
# 0       Adachi            Restaurant        Japanese Restaurant
# 1      Arakawa      Ramen Restaurant         Chinese Restaurant
# 2       Bunkyō     Indian Restaurant         Chinese Restaurant
# 3      Chiyoda      Ramen Restaurant         Chinese Restaurant
# 4         Chūō      Sushi Restaurant        Japanese Restaurant
# 5      Edogawa      Ramen Restaurant         Italian Restaurant
# 6     Itabashi    Chinese Restaurant         Italian Restaurant
# 7   Katsushika    Donburi Restaurant           Ramen Restaurant
# 8         Kita            Restaurant  South American Restaurant
# 9         Kōtō    Chinese Restaurant                 Restaurant
# 10      Meguro    Chinese Restaurant        Japanese Restaurant
# 11      Minato       Soba Restaurant        Yakitori Restaurant
# 12      Nakano      Ramen Restaurant         Italian Restaurant
# 13      Nerima    Chinese Restaurant         Yoshoku Restaurant
# 14    Setagaya      Ramen Restaurant                 Restaurant
# 15     Shibuya    Chinese Restaurant           Ramen Restaurant
# 16   Shinagawa    Donburi Restaurant                 Restaurant
# 17    Shinjuku      Ramen Restaurant         Chinese Restaurant
# 18    Suginami      Ramen Restaurant         Italian Restaurant
# 19      Sumida   Japanese Restaurant           Unagi Restaurant
# 20       Taitō       Soba Restaurant           Ramen Restaurant
# 21     Toshima      Ramen Restaurant        Japanese Restaurant
# 22         Ōta      Ramen Restaurant        Japanese Restaurant
#
#             3rd Most Common Venue      4th Most Common Venue  \
# 0              Italian Restaurant         Yoshoku Restaurant
# 1              Italian Restaurant         Donburi Restaurant
# 2             Japanese Restaurant        Szechuan Restaurant
# 3       Japanese Curry Restaurant          Indian Restaurant
# 4                 Soba Restaurant         Italian Restaurant
# 5              Yoshoku Restaurant          Indian Restaurant
# 6              Yoshoku Restaurant          Indian Restaurant
# 7               Korean Restaurant        Dumpling Restaurant
# 8   Vegetarian / Vegan Restaurant  Cajun / Creole Restaurant
# 9              Yoshoku Restaurant          Indian Restaurant
# 10               Sushi Restaurant         Italian Restaurant
# 11              Kosher Restaurant         Chinese Restaurant
# 12             Chinese Restaurant         Donburi Restaurant
# 13              Indian Restaurant      Kushikatsu Restaurant
# 14               Unagi Restaurant        Japanese Restaurant
# 15              French Restaurant           Sushi Restaurant
# 16            Japanese Restaurant            Soba Restaurant
# 17            Japanese Restaurant         Italian Restaurant
# 18               Asian Restaurant         Chinese Restaurant
# 19             Chinese Restaurant        Tonkatsu Restaurant
# 20            Japanese Restaurant           Sushi Restaurant
# 21             Chinese Restaurant            Soba Restaurant
# 22             Chinese Restaurant        Tonkatsu Restaurant
#
#     5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 0       Indian Restaurant  Kushikatsu Restaurant     Kosher Restaurant
# 1       Korean Restaurant    Japanese Restaurant     Indian Restaurant
# 2      Yoshoku Restaurant  Kushikatsu Restaurant     Kosher Restaurant
# 3       French Restaurant    Japanese Restaurant            Restaurant
# 4      Seafood Restaurant       Unagi Restaurant    Donburi Restaurant
# 5   Kushikatsu Restaurant      Kosher Restaurant     Korean Restaurant
# 6   Kushikatsu Restaurant      Kosher Restaurant     Korean Restaurant
# 7     Japanese Restaurant      Indian Restaurant    Yoshoku Restaurant
# 8      Seafood Restaurant      French Restaurant    Yoshoku Restaurant
# 9   Kushikatsu Restaurant      Kosher Restaurant     Korean Restaurant
# 10      Hotpot Restaurant  Kushikatsu Restaurant     Kosher Restaurant
# 11       Kebab Restaurant     Kaiseki Restaurant     French Restaurant
# 12      Korean Restaurant    Japanese Restaurant    Yoshoku Restaurant
# 13      Kosher Restaurant      Korean Restaurant      Kebab Restaurant
# 14   Fast Food Restaurant    Szechuan Restaurant    Yoshoku Restaurant
# 15    Japanese Restaurant   Brazilian Restaurant  Mongolian Restaurant
# 16       Sushi Restaurant     Yoshoku Restaurant     Indian Restaurant
# 17        Soba Restaurant    Tonkatsu Restaurant    Yoshoku Restaurant
# 18    Dumpling Restaurant        Soba Restaurant   Japanese Restaurant
# 19       Ramen Restaurant     Yoshoku Restaurant     Indian Restaurant
# 20    Sukiyaki Restaurant     Italian Restaurant  Monjayaki Restaurant
# 21     Yoshoku Restaurant     Donburi Restaurant    Dongbei Restaurant
# 22    Dumpling Restaurant     Italian Restaurant      Sushi Restaurant
#
#         8th Most Common Venue      9th Most Common Venue  \
# 0           Korean Restaurant           Kebab Restaurant
# 1          Yoshoku Restaurant      Kushikatsu Restaurant
# 2           Korean Restaurant           Kebab Restaurant
# 3          Italian Restaurant           Sushi Restaurant
# 4          Tempura Restaurant           Ramen Restaurant
# 5            Kebab Restaurant         Kaiseki Restaurant
# 6            Kebab Restaurant         Kaiseki Restaurant
# 7          Italian Restaurant      Kushikatsu Restaurant
# 8          Italian Restaurant          Korean Restaurant
# 9            Kebab Restaurant         Kaiseki Restaurant
# 10          Korean Restaurant           Kebab Restaurant
# 11        Japanese Restaurant          Indian Restaurant
# 12      Kushikatsu Restaurant          Kosher Restaurant
# 13         Kaiseki Restaurant        Japanese Restaurant
# 14          Indian Restaurant          Korean Restaurant
# 15         Donburi Restaurant     Shabu-Shabu Restaurant
# 16          Kosher Restaurant          Korean Restaurant
# 17       Brazilian Restaurant        Yakitori Restaurant
# 18          Kosher Restaurant          Korean Restaurant
# 19          Kosher Restaurant          Korean Restaurant
# 20           Unagi Restaurant         Chinese Restaurant
# 21  Middle Eastern Restaurant            Thai Restaurant
# 22         Yoshoku Restaurant  Japanese Curry Restaurant
#
#        10th Most Common Venue
# 0          Kaiseki Restaurant
# 1           Kosher Restaurant
# 2          Kaiseki Restaurant
# 3             Soba Restaurant
# 4          Yoshoku Restaurant
# 5         Japanese Restaurant
# 6         Japanese Restaurant
# 7           Kosher Restaurant
# 8            Kebab Restaurant
# 9         Japanese Restaurant
# 10         Kaiseki Restaurant
# 11         Italian Restaurant
# 12           Kebab Restaurant
# 13  Japanese Curry Restaurant
# 14           Kebab Restaurant
# 15    South Indian Restaurant
# 16           Kebab Restaurant
# 17            Thai Restaurant
# 18           Kebab Restaurant
# 19           Kebab Restaurant
# 20            Nabe Restaurant
# 21        Tonkatsu Restaurant
# 22          Korean Restaurant

# %% [markdown]
# ### 4. Cluster data

# %% [markdown]
# ### Data is clustered into five clusters

# %%
kclusters = 5
Tokyo_grouped_clustering = Tokyo_grouped_r.drop('Ward', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Tokyo_grouped_clustering)
kmeans.labels_[0:10]
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
tokyo_merged = df
tokyo_merged.rename(columns={'Name':'Ward'}, inplace=True)
tokyo_merged = tokyo_merged.join(neighborhoods_venues_sorted.set_index('Ward'), on='Ward')
tokyo_merged.head()
# Out:
#   No.      Ward  Population  Density   Area  \
# 0  01   Chiyoda       59441     5100  11.66
# 1  02      Chūō      147620    14460  10.21
# 2  03    Minato      248071    12180  20.37
# 3  04  Shinjuku      339211    18620  18.22
# 4  05    Bunkyō      223389    19790  11.29
#
#                                      Major districts   Latitude   Longitude  \
# 0  Nagatachō, Kasumigaseki, Ōtemachi, Marunouchi,...  35.693810  139.753216
# 1  Nihonbashi, Kayabachō, Ginza, Tsukiji, Hatchōb...  35.666255  139.775565
# 2  Odaiba, Shinbashi, Hamamatsuchō, Mita, Roppong...  35.643227  139.740055
# 3  Shinjuku, Takadanobaba, Ōkubo, Kagurazaka, Ich...  35.693763  139.703632
# 4                              Hongō, Yayoi, Hakusan  35.718810  139.744732
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               1      Ramen Restaurant    Chinese Restaurant
# 1               0      Sushi Restaurant   Japanese Restaurant
# 2               1       Soba Restaurant   Yakitori Restaurant
# 3               1      Ramen Restaurant    Chinese Restaurant
# 4               0     Indian Restaurant    Chinese Restaurant
#
#        3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0  Japanese Curry Restaurant     Indian Restaurant     French Restaurant
# 1            Soba Restaurant    Italian Restaurant    Seafood Restaurant
# 2          Kosher Restaurant    Chinese Restaurant      Kebab Restaurant
# 3        Japanese Restaurant    Italian Restaurant       Soba Restaurant
# 4        Japanese Restaurant   Szechuan Restaurant    Yoshoku Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0    Japanese Restaurant            Restaurant    Italian Restaurant
# 1       Unagi Restaurant    Donburi Restaurant    Tempura Restaurant
# 2     Kaiseki Restaurant     French Restaurant   Japanese Restaurant
# 3    Tonkatsu Restaurant    Yoshoku Restaurant  Brazilian Restaurant
# 4  Kushikatsu Restaurant     Kosher Restaurant     Korean Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Sushi Restaurant        Soba Restaurant
# 1      Ramen Restaurant     Yoshoku Restaurant
# 2     Indian Restaurant     Italian Restaurant
# 3   Yakitori Restaurant        Thai Restaurant
# 4      Kebab Restaurant     Kaiseki Restaurant

# %% [markdown]
# ### Cluster 0

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 0, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#       Ward                                    Major districts   Latitude  \
# 1     Chūō  Nihonbashi, Kayabachō, Ginza, Tsukiji, Hatchōb...  35.666255
# 4   Bunkyō                              Hongō, Yayoi, Hakusan  35.718810
# 9   Meguro     Meguro, Nakameguro, Jiyugaoka, Komaba, Aobadai  35.621250
# 20  Adachi                      Ayase, Kitasenju, Takenotsuka  35.783703
#
#      Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1   139.775565               0      Sushi Restaurant   Japanese Restaurant
# 4   139.744732               0     Indian Restaurant    Chinese Restaurant
# 9   139.688014               0    Chinese Restaurant   Japanese Restaurant
# 20  139.795319               0            Restaurant   Japanese Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1        Soba Restaurant    Italian Restaurant    Seafood Restaurant
# 4    Japanese Restaurant   Szechuan Restaurant    Yoshoku Restaurant
# 9       Sushi Restaurant    Italian Restaurant     Hotpot Restaurant
# 20    Italian Restaurant    Yoshoku Restaurant     Indian Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1        Unagi Restaurant    Donburi Restaurant    Tempura Restaurant
# 4   Kushikatsu Restaurant     Kosher Restaurant     Korean Restaurant
# 9   Kushikatsu Restaurant     Kosher Restaurant     Korean Restaurant
# 20  Kushikatsu Restaurant     Kosher Restaurant     Korean Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 1       Ramen Restaurant     Yoshoku Restaurant
# 4       Kebab Restaurant     Kaiseki Restaurant
# 9       Kebab Restaurant     Kaiseki Restaurant
# 20      Kebab Restaurant     Kaiseki Restaurant

# %% [markdown]
# ### Cluster 1

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 1, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#           Ward                                    Major districts   Latitude  \
# 0      Chiyoda  Nagatachō, Kasumigaseki, Ōtemachi, Marunouchi,...  35.693810
# 2       Minato  Odaiba, Shinbashi, Hamamatsuchō, Mita, Roppong...  35.643227
# 3     Shinjuku  Shinjuku, Takadanobaba, Ōkubo, Kagurazaka, Ich...  35.693763
# 5        Taitō                                      Ueno, Asakusa  35.717450
# 6       Sumida                      Kinshichō, Morishita, Ryōgoku  35.700429
# 8    Shinagawa  Shinagawa, Gotanda, Ōsaki, Hatanodai, Ōimachi,...  35.599252
# 10         Ōta                Ōmori, Kamata, Haneda, Den-en-chōfu  35.561206
# 11    Setagaya  Setagaya, Shimokitazawa, Kinuta, Karasuyama, T...  35.646096
# 12     Shibuya  Shibuya, Ebisu, Harajuku, Daikanyama, Hiroo, S...  35.664596
# 13      Nakano                                             Nakano  35.718123
# 14    Suginami                           Kōenji, Asagaya, Ogikubo  35.699493
# 15     Toshima               Ikebukuro, Komagome, Senkawa, Sugamo  35.736156
# 17     Arakawa             Arakawa, Machiya, Nippori, Minamisenju  35.737529
# 21  Katsushika                 Tateishi, Aoto, Kameari, Shibamata  35.751733
#
#      Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0   139.753216               1      Ramen Restaurant    Chinese Restaurant
# 2   139.740055               1       Soba Restaurant   Yakitori Restaurant
# 3   139.703632               1      Ramen Restaurant    Chinese Restaurant
# 5   139.790859               1       Soba Restaurant      Ramen Restaurant
# 6   139.805017               1   Japanese Restaurant      Unagi Restaurant
# 8   139.738910               1    Donburi Restaurant            Restaurant
# 10  139.715843               1      Ramen Restaurant   Japanese Restaurant
# 11  139.656270               1      Ramen Restaurant            Restaurant
# 12  139.698711               1    Chinese Restaurant      Ramen Restaurant
# 13  139.664468               1      Ramen Restaurant    Italian Restaurant
# 14  139.636288               1      Ramen Restaurant    Italian Restaurant
# 15  139.714222               1      Ramen Restaurant   Japanese Restaurant
# 17  139.781310               1      Ramen Restaurant    Chinese Restaurant
# 21  139.863816               1    Donburi Restaurant      Ramen Restaurant
#
#         3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0   Japanese Curry Restaurant     Indian Restaurant     French Restaurant
# 2           Kosher Restaurant    Chinese Restaurant      Kebab Restaurant
# 3         Japanese Restaurant    Italian Restaurant       Soba Restaurant
# 5         Japanese Restaurant      Sushi Restaurant   Sukiyaki Restaurant
# 6          Chinese Restaurant   Tonkatsu Restaurant      Ramen Restaurant
# 8         Japanese Restaurant       Soba Restaurant      Sushi Restaurant
# 10         Chinese Restaurant   Tonkatsu Restaurant   Dumpling Restaurant
# 11           Unagi Restaurant   Japanese Restaurant  Fast Food Restaurant
# 12          French Restaurant      Sushi Restaurant   Japanese Restaurant
# 13         Chinese Restaurant    Donburi Restaurant     Korean Restaurant
# 14           Asian Restaurant    Chinese Restaurant   Dumpling Restaurant
# 15         Chinese Restaurant       Soba Restaurant    Yoshoku Restaurant
# 17         Italian Restaurant    Donburi Restaurant     Korean Restaurant
# 21          Korean Restaurant   Dumpling Restaurant   Japanese Restaurant
#
#    6th Most Common Venue 7th Most Common Venue      8th Most Common Venue  \
# 0    Japanese Restaurant            Restaurant         Italian Restaurant
# 2     Kaiseki Restaurant     French Restaurant        Japanese Restaurant
# 3    Tonkatsu Restaurant    Yoshoku Restaurant       Brazilian Restaurant
# 5     Italian Restaurant  Monjayaki Restaurant           Unagi Restaurant
# 6     Yoshoku Restaurant     Indian Restaurant          Kosher Restaurant
# 8     Yoshoku Restaurant     Indian Restaurant          Kosher Restaurant
# 10    Italian Restaurant      Sushi Restaurant         Yoshoku Restaurant
# 11   Szechuan Restaurant    Yoshoku Restaurant          Indian Restaurant
# 12  Brazilian Restaurant  Mongolian Restaurant         Donburi Restaurant
# 13   Japanese Restaurant    Yoshoku Restaurant      Kushikatsu Restaurant
# 14       Soba Restaurant   Japanese Restaurant          Kosher Restaurant
# 15    Donburi Restaurant    Dongbei Restaurant  Middle Eastern Restaurant
# 17   Japanese Restaurant     Indian Restaurant         Yoshoku Restaurant
# 21     Indian Restaurant    Yoshoku Restaurant         Italian Restaurant
#
#         9th Most Common Venue   10th Most Common Venue
# 0            Sushi Restaurant          Soba Restaurant
# 2           Indian Restaurant       Italian Restaurant
# 3         Yakitori Restaurant          Thai Restaurant
# 5          Chinese Restaurant          Nabe Restaurant
# 6           Korean Restaurant         Kebab Restaurant
# 8           Korean Restaurant         Kebab Restaurant
# 10  Japanese Curry Restaurant        Korean Restaurant
# 11          Korean Restaurant         Kebab Restaurant
# 12     Shabu-Shabu Restaurant  South Indian Restaurant
# 13          Kosher Restaurant         Kebab Restaurant
# 14          Korean Restaurant         Kebab Restaurant
# 15            Thai Restaurant      Tonkatsu Restaurant
# 17      Kushikatsu Restaurant        Kosher Restaurant
# 21      Kushikatsu Restaurant        Kosher Restaurant

# %% [markdown]
# ### Cluster 2

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 2, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#     Ward                                    Major districts   Latitude  \
# 7   Kōtō  Kiba, Ariake, Kameido, Tōyōchō, Monzennakachō,...  35.649154
# 16  Kita                               Akabane, Ōji, Tabata  -0.220164
#
#      Longitude  Cluster Labels 1st Most Common Venue  \
# 7   139.812790               2    Chinese Restaurant
# 16  -78.512327               2            Restaurant
#
#         2nd Most Common Venue          3rd Most Common Venue  \
# 7                  Restaurant             Yoshoku Restaurant
# 16  South American Restaurant  Vegetarian / Vegan Restaurant
#
#         4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 7           Indian Restaurant  Kushikatsu Restaurant     Kosher Restaurant
# 16  Cajun / Creole Restaurant     Seafood Restaurant     French Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 7      Korean Restaurant      Kebab Restaurant    Kaiseki Restaurant
# 16    Yoshoku Restaurant    Italian Restaurant     Korean Restaurant
#
#    10th Most Common Venue
# 7     Japanese Restaurant
# 16       Kebab Restaurant

# %% [markdown]
# ### Cluster 3

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 3, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#         Ward              Major districts   Latitude   Longitude  \
# 18  Itabashi     Itabashi, Takashimadaira  35.774143  139.681209
# 19    Nerima  Nerima, Ōizumi, Hikarigaoka  35.748360  139.638735
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 18               3    Chinese Restaurant    Italian Restaurant
# 19               3    Chinese Restaurant    Yoshoku Restaurant
#
#    3rd Most Common Venue  4th Most Common Venue  5th Most Common Venue  \
# 18    Yoshoku Restaurant      Indian Restaurant  Kushikatsu Restaurant
# 19     Indian Restaurant  Kushikatsu Restaurant      Kosher Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18     Kosher Restaurant     Korean Restaurant      Kebab Restaurant
# 19     Korean Restaurant      Kebab Restaurant    Kaiseki Restaurant
#
#    9th Most Common Venue     10th Most Common Venue
# 18    Kaiseki Restaurant        Japanese Restaurant
# 19   Japanese Restaurant  Japanese Curry Restaurant

# %% [markdown]
# ### Cluster 4

# %%
tokyo_merged.loc[tokyo_merged['Cluster Labels'] == 4, tokyo_merged.columns[[1] + list(range(5, tokyo_merged.shape[1]))]]
# Out:
#        Ward Major districts   Latitude   Longitude  Cluster Labels  \
# 22  Edogawa    Kasai, Koiwa  35.678278  139.871091               4
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 22      Ramen Restaurant    Italian Restaurant    Yoshoku Restaurant
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 22     Indian Restaurant  Kushikatsu Restaurant     Kosher Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 22     Korean Restaurant      Kebab Restaurant    Kaiseki Restaurant
#
#    10th Most Common Venue
# 22    Japanese Restaurant

# %% [markdown]
# <br />
#
# ### 5. Generate map of Tokyo and map clusters

# %% [markdown]
# ### Geographic coordinates for Tokyo, Japan

# %%
address = 'Tokyo, JP'

geolocator = Nominatim(user_agent="Tokyo_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Tokyo are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Tokyo are 35.6828387, 139.7594549.

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         713 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.1.0-py_1 conda-forge
#     branca:  0.4.1-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

markers_colors = []
for lat, lon, poi, cluster in zip(tokyo_merged['Latitude'], tokyo_merged['Longitude'], tokyo_merged['Ward'], tokyo_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
    

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
